# %% [markdown]
# # Here, we make Figure 6, showing the numerical solutions when parameters are varied.

# %%
import matplotlib.pyplot as plt
import xarray as xr
from matplotlib import rcParams
import seaborn as sns

# %% [markdown]
# # Load in the saved runs from different parameter set-ups.
# These files were created from the execute files in folders such as 100m_rhodiff2, 250m_rhodiff2, 250m_rhodiff3.

# %%
# First load in 250m and Delta rho is 3
rho3=1032 #density abyssal fluid
rho2=1029 #density bottom active layer
rho1=1026 #density top active layer

# Top perturbation
h2=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h2_xr_control_years0to75_toplayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho3_mitdomainsize_mod.nc")
h2_xr_top3=(h2.to_array()).squeeze()

h1=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h1_xr_control_years0to75_toplayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho3_mitdomainsize_mod.nc")
h1_xr_top3=(h1.to_array()).squeeze()


# Bottom perturbation
h2=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h2_xr_control_years0to75_bottomlayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho3_mitdomainsize_mod.nc")
h2_xr_bottom3=(h2.to_array()).squeeze()

h1=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h1_xr_control_years0to75_bottomlayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho3_mitdomainsize_mod.nc")
h1_xr_bottom3=(h1.to_array()).squeeze()

# %%
# Next load in 250m and Delta rho is 2
rho3=1030 #density abyssal fluid
rho2=1028 #density bottom active layer
rho1=1026 #density top active layer

#Top perturbation
h2=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h2_xr_control_years0to75_toplayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho2_mitdomainsize_mod.nc")
h2_xr_top2=(h2.to_array()).squeeze()

h1=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h1_xr_control_years0to75_toplayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho2_mitdomainsize_mod.nc")
h1_xr_top2=(h1.to_array()).squeeze()

#Bottom perturbation
h2=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h2_xr_control_years0to75_bottomlayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho2_mitdomainsize_mod.nc")
h2_xr_bottom2=(h2.to_array()).squeeze()

h1=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h1_xr_control_years0to75_bottomlayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_250_H2_250_delta_rho2_mitdomainsize_mod.nc")
h1_xr_bottom2=(h1.to_array()).squeeze()

# %%
# Load in 100 m and Delta rho is 2
rho3=1030 #density abyssal fluid
rho2=1028 #density bottom active layer
rho1=1026 #density top active layer

#Top perturbation
h2=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h2_xr_control_years0to75_toplayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_100_H2_100_delta_rho2_mitdomainsize_mod.nc")
h2_xr_top100=(h2.to_array()).squeeze()

h1=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h1_xr_control_years0to75_toplayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_100_H2_100_delta_rho2_mitdomainsize_mod.nc")
h1_xr_top100=(h1.to_array()).squeeze()

#Bottom perturbation
h2=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h2_xr_control_years0to75_bottomlayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_100_H2_100_delta_rho2_mitdomainsize_mod.nc")
h2_xr_bottom100=(h2.to_array()).squeeze()

h1=xr.open_dataset("/scratch/abf376/2.5layer_reducedgravitymodel/saved_runs/h1_xr_control_years0to75_bottomlayerpert_fix_fromstationary_northofsponge_nohdamp_sealevel_tunedtomitgcm_nu8e3_dt250_rk4_nohdiffusion_noslip_properimplement_update_onlycorners_nonlinear_H1_100_H2_100_delta_rho2_mitdomainsize_mod.nc")
h1_xr_bottom100=(h1.to_array()).squeeze()

# %%
sns.set_style(style="whitegrid") #comment out if don't want seaborn background


scaling=1 #use 1 if half width plot once put into latex. use 1/2 if full width once put into latex

rcParams.update({
    'font.size': 10 * scaling,
    'axes.titlesize': 15 * scaling,
    'axes.labelsize': 14 * scaling,
    'xtick.labelsize': 13 * scaling,
    'ytick.labelsize': 13 * scaling,
    'legend.fontsize': 11 * scaling,
})


custom_dash_pattern = (0, (4,3, 1, 3, 1, 3)) #this is a custom line style to try to distinguish experiments better



fig,(ax)=plt.subplots(nrows=1,ncols=1,figsize=(6.47,10.5/3+0.8), constrained_layout=True)

asymp_top=(h1_xr_top3+h2_xr_top3)
asymp_top2=(h1_xr_top2+h2_xr_top2)
asymp_top100=(h1_xr_top100+h2_xr_top100)

asymp_bottom=(h1_xr_bottom3+h2_xr_bottom3)
asymp_bottom2=(h1_xr_bottom2+h2_xr_bottom2)
asymp_bottom100=(h1_xr_bottom100+h2_xr_bottom100)

ax.plot(asymp_top.time/360,100*(asymp_top2.where(asymp_top.y>0).mean('x').mean('y')-asymp_top2.mean('x').mean('y')),color='tab:blue',lw=3,label=r'Top layer perturbation, H1=H2=250m, $\Delta \rho=2$')
ax.plot(asymp_top.time/360,100*(asymp_bottom2.where(asymp_bottom.y>0).mean('x').mean('y')-asymp_bottom2.mean('x').mean('y')),color='tab:orange',lw=3,label=r'Bottom layer perturbation, H1=H2=250m, $\Delta \rho=2$')
ax.plot(asymp_top.time/360,100*(asymp_top.where(asymp_top.y>0).mean('x').mean('y')-asymp_top.mean('x').mean('y')),color='tab:blue',linestyle='dashed',lw=3,label=r'Top layer perturbation, H1=H2=250m, $\Delta \rho=3$')
ax.plot(asymp_top.time/360,100*(asymp_bottom.where(asymp_bottom.y>0).mean('x').mean('y')-asymp_bottom.mean('x').mean('y')),color='tab:orange',linestyle='dashed',lw=3,label=r'Bottom layer perturbation, H1=H2=250m, $\Delta \rho=3$')
ax.plot(asymp_top100.time/360,100*(asymp_top100.where(asymp_top100.y>0).mean('x').mean('y')-asymp_top100.mean('x').mean('y')),color='tab:blue',linestyle= custom_dash_pattern,lw=3,label=r'Top layer perturbation, H1=H2=100m, $\Delta \rho=2$')
ax.plot(asymp_top100.time/360,100*(asymp_bottom100.where(asymp_bottom100.y>0).mean('x').mean('y')-asymp_bottom100.mean('x').mean('y')),color='tab:orange',lw=3,linestyle= custom_dash_pattern,label=r'Bottom layer perturbation, H1=H2=100m, $\Delta \rho=2$')


ax.set_ylabel('Height (cm)')
ax.set_xlabel('Years')

ax.set_title(r'Varied $H$ and $\Delta \rho$')

from matplotlib.lines import Line2D

#this solution here is to help with legend alignment. To have the three columns, we assign a line with 0 weight.
custom_lines = [
    Line2D([0], [0], color='white', lw=0, label=r'H=250m, $\Delta \rho=2$'),
    Line2D([0], [0], color='tab:blue',lw=2.5,label='Top pert.'),
    Line2D([0], [0], color='tab:orange',lw=2.5,label='Bottom pert.'),
    Line2D([0], [0], color='white', lw=0, label=r'H=250m, $\Delta \rho=3$'),
    Line2D([0], [0], color='tab:blue',lw=2.5, linestyle='dashed',label='Top pert.'),
    Line2D([0], [0], color='tab:orange', lw=2.5,linestyle='dashed',label='Bottom pert.'),
    Line2D([0], [0], color='white', lw=0, label=r'H=100m, $\Delta \rho=2$'),
    Line2D([0], [0], color='tab:blue',lw=2.5, linestyle=custom_dash_pattern,label='Top pert.'),
    Line2D([0], [0], color='tab:orange',lw=2.5, linestyle=custom_dash_pattern,label='Bottom pert.')
]


legend1 = ax.legend(handles=custom_lines, loc='upper center', bbox_to_anchor=(0.50, -0.2), ncol=3,columnspacing=1.105)

# adjust alignment of legend
for text in legend1.get_texts():
    if 'H=' in text.get_text():
        text.set_ha('left')
        text.set_x(-32)  # adjust if needed


ax.set_ylabel('Height (cm)')
ax.set_xlabel('Years')
ax.set_xticks(np.arange(0, 76, 25)) # show x-ticks every 25 years

fig.suptitle('Change in Northern Hemisphere anomaly \n of upper ocean thickness', fontsize=18*scaling, y=1.135, fontweight='bold')

import matplotlib
plt.savefig('parametersweep_newlegend_layerthickness_titlechange.pdf',dpi=1000,bbox_inches='tight')
